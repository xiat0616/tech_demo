# %% [markdown]
# ### Abnormal IDs: [17172, 18662, 25724, 37227, 40792, 43924, 44741, 46418, 53428, 55204, 57985]

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from skimage import io

# Define the root directory and image ID
PADCHEST_ROOT = Path("/vol/biodata/data/chest_xray/BIMCV-PADCHEST")
IMAGE_ID = "216840111366964013307756408102012075114409726_01-085-083.png"
PADCHEST_IMAGES = PADCHEST_ROOT / "images"
image_path = PADCHEST_IMAGES / IMAGE_ID

# Check if the file exists
if not image_path.exists():
    print(f"File not found: {image_path}")
else:
    # Read the image as grayscale
    image = io.imread(image_path, as_gray=True)

    # Plot the image
    plt.figure(figsize=(8, 8))
    plt.imshow(image, cmap='gray')
    plt.title(f"Image: {IMAGE_ID}", fontsize=16)
    plt.axis("off")
    plt.show()
